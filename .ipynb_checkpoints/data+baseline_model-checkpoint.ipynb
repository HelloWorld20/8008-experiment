# %%
import pandas as pd
import numpy as np

# %%
sell_price = pd.read_csv('dataset/sell_prices.csv')
calendar = pd.read_csv('dataset/calendar.csv')
train = pd.read_csv('dataset/sales_train_evaluation.csv')

# %%
sell_price.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
train.head()
# Out:
#          item_id    dept_id   cat_id store_id state_id  d_1  d_2  d_3  d_4  \
# 0  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 1  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 2  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 3  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 4  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
#
#    d_5  ...  d_1932  d_1933  d_1934  d_1935  d_1936  d_1937  d_1938  d_1939  \
# 0    0  ...       2       4       0       0       0       0       3       3
# 1    0  ...       0       1       2       1       1       0       0       0
# 2    0  ...       1       0       2       0       0       0       2       3
# 3    0  ...       1       1       0       4       0       1       3       0
# 4    0  ...       0       0       0       2       1       0       0       2
#
#    d_1940  d_1941
# 0       0       1
# 1       0       0
# ...

# %%
# Get column groups
cat_cols = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']
ts_cols = [col for col in train.columns if col not in cat_cols]
ts_dict = {t: int(t[2:]) for t in ts_cols}

# Describe data
print('  unique forecasts: %i' % train.shape[0])
for col in cat_cols:
    print('   N_unique %s: %i' % (col, train[col].nunique()))
# Out:
#   unique forecasts: 30490
#    N_unique item_id: 3049
#    N_unique dept_id: 7
#    N_unique cat_id: 3
#    N_unique store_id: 10
#    N_unique state_id: 3

# %%
# 1. All products, all stores, all states (1 series)
all_sales = pd.DataFrame(train[ts_cols].sum()).transpose()
all_sales['id_str'] = 'all'
all_sales = all_sales[ ['id_str'] +  [c for c in all_sales if c not in ['id_str']] ]
all_sales
# Out:
#   id_str    d_1    d_2    d_3    d_4    d_5    d_6    d_7    d_8    d_9  ...  \
# 0    all  32631  31749  23783  25412  19146  29211  28010  37932  32736  ...
#
#    d_1932  d_1933  d_1934  d_1935  d_1936  d_1937  d_1938  d_1939  d_1940  \
# 0   44073   54308   59921   42362   38777   37096   36963   42552   51518
#
#    d_1941
# 0   54338
#
# [1 rows x 1942 columns]

# %%
# 2. All products by state (3 series)
state_sales = train.groupby('state_id',as_index=False)[ts_cols].sum()
state_sales['id_str'] = state_sales['state_id'] 
state_sales = state_sales[ ['id_str'] +  [c for c in state_sales if c not in ['id_str']] ]
state_sales = state_sales.drop(['state_id'],axis=1)
state_sales
# Out:
#   id_str    d_1    d_2    d_3    d_4   d_5    d_6    d_7    d_8    d_9  ...  \
# 0     CA  14195  13805  10108  11047  9925  11322  12251  16610  14696  ...
# 1     TX   9438   9630   6778   7381  5912   9006   6226   9440   9376  ...
# 2     WI   8998   8314   6897   6984  3309   8883   9533  11882   8664  ...
#
#    d_1932  d_1933  d_1934  d_1935  d_1936  d_1937  d_1938  d_1939  d_1940  \
# 0   18471   23037   24704   17721   16150   15678   16297   17430   23103
# 1   12320   12366   16249   12228   11370   10375    9162   12303   13681
# 2   13282   18905   18968   12413   11257   11043   11504   12819   14734
#
#    d_1941
# 0   24644
# 1   14815
# 2   14879
#
# [3 rows x 1942 columns]

# %%
# 3. All products by store (10 series)
store_sales = train.groupby('store_id',as_index=False)[ts_cols].sum()
store_sales['id_str'] = store_sales['store_id'] 
store_sales = store_sales[ ['id_str'] +  [c for c in store_sales if c not in ['id_str']] ]
store_sales = store_sales.drop(['store_id'],axis=1)
store_sales
# Out:
#   id_str   d_1   d_2   d_3   d_4   d_5   d_6   d_7   d_8   d_9  ...  d_1932  \
# 0   CA_1  4337  4155  2816  3051  2630  3276  3450  5437  4340  ...    4951
# 1   CA_2  3494  3046  2121  2324  1942  2288  2629  3729  2957  ...    4839
# 2   CA_3  4739  4827  3785  4232  3817  4369  4703  5456  5581  ...    6046
# 3   CA_4  1625  1777  1386  1440  1536  1389  1469  1988  1818  ...    2635
# 4   TX_1  2556  2687  1822  2258  1694  2734  1691  2820  2887  ...    3610
# 5   TX_2  3852  3937  2731  2954  2492  3439  2588  3772  3657  ...    4415
# 6   TX_3  3030  3006  2225  2169  1726  2833  1947  2848  2832  ...    4295
# 7   WI_1  2704  2194  1562  1251     2  2049  2815  3248  1674  ...    3978
# 8   WI_2  2256  1922  2018  2522  1175  2244  2232  2643  2140  ...    5317
# 9   WI_3  4038  4198  3317  3211  2132  4590  4486  5991  4850  ...    3987
#
#    d_1933  d_1934  d_1935  d_1936  d_1937  d_1938  d_1939  d_1940  d_1941
# ...

# %%
# 4. All products by category (3 series)
cat_sales = train.groupby('cat_id',as_index=False)[ts_cols].sum()
cat_sales['id_str'] = cat_sales['cat_id'] 
cat_sales = cat_sales[ ['id_str'] +  [c for c in cat_sales if c not in ['id_str']] ]
cat_sales = cat_sales.drop(['cat_id'],axis=1)
cat_sales
# Out:
#       id_str    d_1    d_2    d_3    d_4    d_5    d_6    d_7    d_8    d_9  \
# 0      FOODS  23178  22758  17174  18878  14603  22093  20490  27751  24862
# 1    HOBBIES   3764   3357   2682   2669   1814   3220   2944   3986   2899
# 2  HOUSEHOLD   5689   5634   3927   3865   2729   3898   4576   6195   4975
#
#    ...  d_1932  d_1933  d_1934  d_1935  d_1936  d_1937  d_1938  d_1939  \
# 0  ...   30107   36576   41447   29158   26148   24790   24737   28136
# 1  ...    3871    4893    5016    3528    3629    3740    3475    4143
# 2  ...   10095   12839   13458    9676    9000    8566    8751   10273
#
#    d_1940  d_1941
# 0   33599   35967
# 1    5333    5280
# 2   12586   13091
#
# [3 rows x 1942 columns]

# %%
# 5. All products by department (7 series)
dept_sales = train.groupby('dept_id',as_index=False)[ts_cols].sum()
dept_sales['id_str'] = dept_sales['dept_id'] 
dept_sales = dept_sales[ ['id_str'] +  [c for c in dept_sales if c not in ['id_str']] ]
dept_sales = dept_sales.drop(['dept_id'],axis=1)
dept_sales
# Out:
#         id_str    d_1    d_2    d_3    d_4    d_5    d_6    d_7    d_8    d_9  \
# 0      FOODS_1   2343   2216   1657   1508   1209   1897   1903   2235   1925
# 1      FOODS_2   4094   4209   3174   3606   2869   4375   3349   4384   4273
# 2      FOODS_3  16741  16333  12343  13764  10525  15821  15238  21132  18664
# 3    HOBBIES_1   3610   3172   2497   2531   1714   3133   2855   3831   2741
# 4    HOBBIES_2    154    185    185    138    100     87     89    155    158
# 5  HOUSEHOLD_1   4105   3858   2827   2732   1802   2664   3161   4334   3494
# 6  HOUSEHOLD_2   1584   1776   1100   1133    927   1234   1415   1861   1481
#
#    ...  d_1932  d_1933  d_1934  d_1935  d_1936  d_1937  d_1938  d_1939  \
# 0  ...    4130    4257    4225    3264    3119    3073    3251    3735
# 1  ...    5842    7563    9069    6226    5311    4648    4551    4815
# 2  ...   20135   24756   28153   19668   17718   17069   16935   19586
# ...

# %%
# 转成长格式
sales_long = train.melt(
    id_vars=["item_id","dept_id","cat_id","store_id","state_id"],
    var_name="d",
    value_name="sales"
)

# %%
sales_long.head(10)
# Out:
#          item_id    dept_id   cat_id store_id state_id    d  sales
# 0  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0
# 1  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0
# 2  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0
# 3  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0
# 4  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0
# 5  HOBBIES_1_006  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0
# 6  HOBBIES_1_007  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0
# 7  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1       CA  d_1     12
# 8  HOBBIES_1_009  HOBBIES_1  HOBBIES     CA_1       CA  d_1      2
# 9  HOBBIES_1_010  HOBBIES_1  HOBBIES     CA_1       CA  d_1      0

# %%
sales_long.groupby("item_id")["sales"].describe()
# Out:
#                    count      mean       std  min  25%  50%   75%    max
# item_id
# FOODS_1_001      19410.0  0.639052  1.315797  0.0  0.0  0.0   1.0   24.0
# FOODS_1_002      19410.0  0.384596  0.761401  0.0  0.0  0.0   1.0    8.0
# FOODS_1_003      19410.0  0.699536  1.256232  0.0  0.0  0.0   1.0   22.0
# FOODS_1_004      19410.0  6.813550  8.421542  0.0  0.0  4.0  11.0  116.0
# FOODS_1_005      19410.0  1.206543  2.249736  0.0  0.0  0.0   2.0   30.0
# ...                  ...       ...       ...  ...  ...  ...   ...    ...
# HOUSEHOLD_2_512  19410.0  0.603143  1.111164  0.0  0.0  0.0   1.0   17.0
# HOUSEHOLD_2_513  19410.0  0.412777  1.100467  0.0  0.0  0.0   0.0   20.0
# HOUSEHOLD_2_514  19410.0  0.164812  0.449395  0.0  0.0  0.0   0.0    5.0
# HOUSEHOLD_2_515  19410.0  0.059402  0.284820  0.0  0.0  0.0   0.0    6.0
# HOUSEHOLD_2_516  19410.0  0.133282  0.390798  0.0  0.0  0.0   0.0    9.0
#
# [3049 rows x 8 columns]

# %% [markdown]
# 类型	条件	含义
# smooth	ADI < 1.32 且 CV² < 0.49	稳定需求
# erratic	ADI < 1.32 且 CV² ≥ 0.49	波动大
# intermittent	ADI ≥ 1.32 且 CV² < 0.49	偶尔卖
# lumpy	ADI ≥ 1.32 且 CV² ≥ 0.49	很不规律
#
# cv2 = (std / mean) ** 2
# ADI = 平均非零间隔
# ADI = 总天数 / 非零天数

# %%
def compute_adi(x):
    non_zero = (x > 0).sum()
    return len(x) / non_zero if non_zero > 0 else np.nan

def compute_cv2(x):
    mean = x.mean()
    std = x.std()
    return (std / mean) ** 2 if mean > 0 else np.nan

# %%
stats = sales_long.groupby("item_id")["sales"].agg([
    ("mean", "mean"),
    ("std", "std"),
    ("ADI", compute_adi),
    ("CV2", compute_cv2)
]).reset_index()

# %%
stats.head()
# Out:
#        item_id      mean       std       ADI       CV2
# 0  FOODS_1_001  0.639052  1.315797  2.867484  4.239406
# 1  FOODS_1_002  0.384596  0.761401  3.726959  3.919384
# 2  FOODS_1_003  0.699536  1.256232  2.669876  3.224920
# 3  FOODS_1_004  6.813550  8.421542  1.524625  1.527694
# 4  FOODS_1_005  1.206543  2.249736  2.209196  3.476781

# %%
def classify(row):
    if row["ADI"] < 1.32 and row["CV2"] < 0.49:
        return "smooth"
    elif row["ADI"] < 1.32 and row["CV2"] >= 0.49:
        return "erratic"
    elif row["ADI"] >= 1.32 and row["CV2"] < 0.49:
        return "intermittent"
    else:
        return "lumpy"

stats["type"] = stats.apply(classify, axis=1)

# %%
stats.head()
# Out:
#        item_id      mean       std       ADI       CV2   type
# 0  FOODS_1_001  0.639052  1.315797  2.867484  4.239406  lumpy
# 1  FOODS_1_002  0.384596  0.761401  3.726959  3.919384  lumpy
# 2  FOODS_1_003  0.699536  1.256232  2.669876  3.224920  lumpy
# 3  FOODS_1_004  6.813550  8.421542  1.524625  1.527694  lumpy
# 4  FOODS_1_005  1.206543  2.249736  2.209196  3.476781  lumpy

# %%
stats['type'].value_counts()
# Out:
# type
# lumpy      2961
# erratic      82
# smooth        6
# Name: count, dtype: int64

# %%
stats["CV2"].describe()
# Out:
# count    3049.000000
# mean        6.343465
# std         5.959186
# min         0.313519
# 25%         2.502051
# 50%         4.276849
# 75%         8.013566
# max        71.250721
# Name: CV2, dtype: float64

# %% [markdown]
# type
# lumpy      2961
# erratic      82
# smooth        6
# Name: count, dtype: int64
# 数据不平衡 90%是0 模型可能直接预测0
# Due to strong demand heterogeneity (e.g., lumpy vs smooth demand), a single global forecasting model may suffer from bias toward dominant patterns (e.g., zero-heavy series), leading to suboptimal performance.
# 直接说明了分需求预测的合理性
# A global baseline model (trained on all items)
# A segmented modeling approach (trained separately by demand type)

# %% [markdown]
# 简单平均模型 不考虑季节、趋势、门店差异。
# 全局平均：每个商品未来销量 = 历史销量平均。

# %%
# 按 item_id + store_id 计算历史平均销量
baseline = sales_long.groupby(['item_id','store_id'])['sales'].mean().reset_index()
baseline.rename(columns={'sales':'pred'}, inplace=True)

# 生成未来 28 天的预测
future_days = [f'd_{i}' for i in range(1914, 1942)]
for d in future_days:
    baseline[d] = baseline['pred']

# %% [markdown]
# 移动平均或最后 N 天平均
# 用最近 28 天销量平均，预测未来 28 天。
# 更能反映近期趋势。

# %%
# 最近 28 天列名
recent_days = [f'd_{i}' for i in range(1913-28+1, 1913+1)]  # d_1886 ~ d_1913

# 每行商品+门店最近 28 天平均销量
baseline_values = train[recent_days].mean(axis=1)

# 生成未来 28 天预测列
future_days = [f'd_{i}' for i in range(1914, 1942)]
import numpy as np
baseline = pd.DataFrame(
    np.tile(baseline_values.values.reshape(-1,1), len(future_days)),
    columns=future_days
)

# %%
baseline
# Out:
#          d_1914    d_1915    d_1916    d_1917    d_1918    d_1919    d_1920  \
# 0      0.964286  0.964286  0.964286  0.964286  0.964286  0.964286  0.964286
# 1      0.071429  0.071429  0.071429  0.071429  0.071429  0.071429  0.071429
# 2      0.571429  0.571429  0.571429  0.571429  0.571429  0.571429  0.571429
# 3      1.821429  1.821429  1.821429  1.821429  1.821429  1.821429  1.821429
# 4      1.357143  1.357143  1.357143  1.357143  1.357143  1.357143  1.357143
# ...         ...       ...       ...       ...       ...       ...       ...
# 30485  0.214286  0.214286  0.214286  0.214286  0.214286  0.214286  0.214286
# 30486  0.321429  0.321429  0.321429  0.321429  0.321429  0.321429  0.321429
# 30487  0.892857  0.892857  0.892857  0.892857  0.892857  0.892857  0.892857
# 30488  0.928571  0.928571  0.928571  0.928571  0.928571  0.928571  0.928571
# 30489  1.071429  1.071429  1.071429  1.071429  1.071429  1.071429  1.071429
#
# ...
